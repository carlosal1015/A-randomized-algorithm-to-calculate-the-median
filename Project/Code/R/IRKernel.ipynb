# %% [markdown]
# # IRKernel

# %%
version
# Out:
#                _
# platform       x86_64-pc-linux-gnu
# arch           x86_64
# os             linux-gnu
# system         x86_64, linux-gnu
# status
# major          3
# minor          5.1
# year           2018
# month          07
# day            02
# svn rev        74947
# language       R
# version.string R version 3.5.1 (2018-07-02)
# nickname       Feather Spray

# %% [markdown]
# ## How to install?
#
# Check [this](https://stackoverflow.com/a/44108916).
